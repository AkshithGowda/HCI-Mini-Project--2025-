# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical

# %%
df = pd.read_csv("emotions.csv")   # replace with your actual dataset path

X = df.drop('label', axis=1)
y = df['label']

# %%
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_categorical = to_categorical(y_encoded)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y_categorical, test_size=0.2, random_state=42
)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = Sequential([
    Dense(256, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(y_categorical.shape[1], activation='softmax')  # Output layer
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# C:\Users\Akshi\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(X_train_scaled, y_train, epochs=25, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9765 - loss: 0.1359 - val_accuracy: 0.9824 - val_loss: 0.0463
# Epoch 2/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9743 - loss: 0.0891 - val_accuracy: 0.9736 - val_loss: 0.0711
# Epoch 3/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9817 - loss: 0.0674 - val_accuracy: 0.9619 - val_loss: 0.1218
# Epoch 4/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9831 - loss: 0.0704 - val_accuracy: 0.9501 - val_loss: 0.1343
# Epoch 5/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9883 - loss: 0.0681 - val_accuracy: 0.9765 - val_loss: 0.0931
# Epoch 6/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9927 - loss: 0.0458 - val_accuracy: 0.9765 - val_loss: 0.1009
# Epoch 7/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9912 - loss: 0.0355 - val_accuracy: 0.9736 - val_loss: 0.1234
# Epoch 8/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9905 - loss: 0.0255 - val_accuracy: 0.9795 - val_loss: 0.0730
# Epoch 9/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9919 - loss: 0.0154 - val_accuracy: 0.9795 - val_loss: 0.0692
# Epoch 10/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9890 - loss: 0.0323 - val_accuracy: 0.9824 - val_loss: 0.0730
# Epoch 11/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9941 - loss: 0.0153 - val_accuracy: 0.9824 - val_loss: 0.1029
# Epoch 12/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0397 - val_accuracy: 0.9824 - val_loss: 0.0594
# Epoch 13/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9941 - loss: 0.0138 - val_accuracy: 0.9824 - val_loss: 0.0702
# Epoch 14/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9934 - loss: 0.0188 - val_accuracy: 0.9883 - val_loss: 0.0453
# Epoch 15/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9934 - loss: 0.0335 - val_accuracy: 0.9765 - val_loss: 0.0652
# Epoch 16/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9956 - loss: 0.0125 - val_accuracy: 0.9795 - val_loss: 0.0794
# Epoch 17/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9985 - loss: 0.0111 - val_accuracy: 0.9765 - val_loss: 0.0829
# Epoch 18/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9993 - loss: 0.0048 - val_accuracy: 0.9765 - val_loss: 0.0880
# Epoch 19/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9941 - loss: 0.0149 - val_accuracy: 0.9795 - val_loss: 0.0542
# Epoch 20/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 8.5644e-04 - val_accuracy: 0.9795 - val_loss: 0.0607
# Epoch 21/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9963 - loss: 0.0118 - val_accuracy: 0.9736 - val_loss: 0.1073
# Epoch 22/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9890 - loss: 0.0645 - val_accuracy: 0.9824 - val_loss: 0.0689
# Epoch 23/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0316 - val_accuracy: 0.9707 - val_loss: 0.0933
# Epoch 24/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9941 - loss: 0.0305 - val_accuracy: 0.9795 - val_loss: 0.0752
# Epoch 25/25
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9978 - loss: 0.0422 - val_accuracy: 0.9736 - val_loss: 0.1453

# %%
loss, accuracy = model.evaluate(X_test_scaled, y_test)
print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9766 - loss: 0.2481
# Test Accuracy: 0.98

# %%
model.save("emotion_model_keras.h5")

import joblib
joblib.dump(scaler, "scaler.pkl")
joblib.dump(le, "label_encoder.pkl")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ['label_encoder.pkl']

# %%
new_input = np.random.rand(1, X_train_scaled.shape[1])   # or your actual EEG data row
new_input_scaled = scaler.transform(new_input)

pred = model.predict(new_input_scaled)
predicted_label = le.inverse_transform([np.argmax(pred)])
print("Predicted Emotion:", predicted_label[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Predicted Emotion: POSITIVE
# C:\Users\Akshi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
